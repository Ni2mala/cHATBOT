# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('bakery_chatbot_dataset_fixed.csv')
df
# Out:
#              intent           user_query  \
# 0          greeting                   Hi
# 1          greeting                Hello
# 2          greeting         Good morning
# 3          greeting            Hey there
# 4          greeting  Hi I need some help
# ..              ...                  ...
# 987       thank_you           Thank you!
# 988         goodbye           Gotta run!
# 989     store_hours               Hours?
# 990  store_location            Location?
# 991    contact_info              Number?
#
#                                           bot_response
# 0    Hello! Welcome to Sweet Haven Bakery. How can ...
# 1    Hi there! Thanks for reaching out. What can I ...
# 2    Good day! Welcome to Sweet Haven Bakery. What ...
# 3    Hello! Welcome to Sweet Haven Bakery. How can ...
# 4    Hi there! Thanks for reaching out. What can I ...
# ..                                                 ...
# 987         You're very welcome! Hope to see you soon!
# 988                      No problem! Have a great day!
# 989  We're open Monday-Saturday 7 AM - 7 PM and Sun...
# 990                       145 Main Street in Downtown!
# 991                                    (555) 123-4567!
#
# [992 rows x 3 columns]

# %%
vectorizer = TfidfVectorizer(stop_words="english")

X = vectorizer.fit_transform(df["user_query"])

while True:
    user_input = input("user: ")

    if user_input.lower() in ["exit", "quit"]:
        print("")
        break

    user_vec = vectorizer.transform([user_input])
    sim = cosine_similarity(user_vec, X)
    best_idx = sim.argmax()

    print("bot:", df.iloc[best_idx]["bot_response"])
# Out:
# bot: Hello! Welcome to Sweet Haven Bakery. How can I help you today?
# bot: Good day! Welcome to Sweet Haven Bakery. What would you like to know?
# bot: We're open Monday through Saturday from 7:00 AM to 7:00 PM and Sunday from 8:00 AM to 5:00 PM.
# bot: Yes! We open at 7:00 AM Monday through Saturday and 8:00 AM on Sundays.
# bot: Hello! Welcome to Sweet Haven Bakery. How can I help you today?
# bot: Yes! We're located at 145 Main Street in Downtown.
# bot: We're in Downtown at 145 Main Street, right across from the city library.
# bot: "You can call us at (555) 123-4567 or email hello@sweethavenbakery.com."
# bot: "Absolutely! All our bread is baked fresh every morning starting at 5 AM."
# bot: "We accept cash and cards but don't currently accept checks. Sorry for any inconvenience!"
# bot: "We don't make bagels, but we have delicious baguettes and other artisan breads!"
# bot: "We're a bakery specializing in breads, pastries, and baked goods. We don't serve prepared meals, but our breads are perfect for lunch!"
